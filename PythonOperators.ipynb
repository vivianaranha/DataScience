# %%
a = 2
b = 6

# %%
a,b
# Out:
# (2, 6)

# %%
#Arithmetic Operators

# %%
a+b
# Out:
# 8

# %%
a-b
# Out:
# -4

# %%
a*b
# Out:
# 12

# %%
a/b
# Out:
# 0.3333333333333333

# %%
#Relational Operators

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
# Logical Operators

# %%
a = True
b = False

# %%
a|b
# Out:
# True

# %%
a&b
# Out:
# False

# %%
a|a
# Out:
# True

# %%
b|b
# Out:
# False

# %%
a&a
# Out:
# True

# %%
b&b
# Out:
# False
